# %% [markdown]
# # 5. Write a program in python to find word/s having maximum number of instances in a given file and replace all its occurrences with “Aligarh”.

# %%
with open('/home/syed/Desktop/Mca/Ranga.txt', 'r') as file:
    text = file.read()
words = text.split()
word_count = {}
for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count.setdefault(word, 1)
print(word_count)
max_count=max(word_count.values())
most_frequent_words = [word for word, count in word_count.items() if count == max_count]
print("Word/s with maximum instances:", most_frequent_words, "with", max_count, "occurrences")
for word in most_frequent_words:
    text = text.replace(word, "Aligarh")
with open('/home/syed/Desktop/Mca/Ranga.txt', 'w') as file:
    file.write(text)
# Out:
# {'The': 10, 'Significance': 1, 'of': 8, 'Inodes': 1, 'in': 7, 'File': 5, 'Management': 1, '1.': 2, 'What': 2, 'is': 14, 'an': 3, 'Inode?': 2, 'An': 2, 'inode': 10, '(index': 1, 'node)': 1, 'a': 9, 'data': 3, 'structure': 1, 'on': 4, 'filesystem': 1, 'that': 7, 'stores': 1, 'all': 2, 'the': 36, 'information': 3, 'about': 2, 'file': 4, 'except': 1, 'its': 4, 'name': 1, 'and': 5, 'actual': 2, 'content.': 1, 'Think': 1, 'it': 1, 'this': 2, 'way:': 1, 'Directory': 1, 'simple': 2, 'table': 1, 'maps': 1, 'Filename': 2, 'to': 10, 'Inode': 5, 'number.': 1, '"master': 1, 'record"': 1, 'for': 4, 'file,': 2, 'containing': 2, 'metadata': 2, 'pointers': 1, 'where': 2, "file's": 7, 'lives': 1, 'disk.': 1, 'When': 1, 'you': 1, 'interact': 1, 'with': 3, 'by': 1, 'name,': 1, 'system': 1, 'first': 1, 'finds': 1, 'number': 6, 'directory,': 2, 'then': 1, 'uses': 2, 'fetch': 1, 'inode,': 1, 'finally': 1, 'access': 1, 'data.': 1, '2.': 2, 'Information': 1, 'Stored': 1, 'typically': 1, 'contains:': 1, 'number:': 1, 'A': 2, 'unique': 1, 'identifier': 1, 'filesystem.': 1, 'Metadata': 1, 'file:': 1, 'Size': 1, 'Device': 1, 'ID': 3, 'device': 2, 'file.': 2, 'User': 1, '(UID)': 1, 'owner.': 1, 'Type': 1, 'Permissions:': 1, 'Group': 1, '(GID)': 1, 'permissions': 1, '(read,': 1, 'write,': 1, 'execute': 1, 'owner,': 2, 'group,': 1, 'others).': 1, 'type': 1, '(regular': 1, 'symbolic': 1, 'link,': 1, 'character/block': 1, 'device,': 1, 'etc.).': 1, 'Timestamps:': 1, 'Access': 1, 'Time': 3, '(atime):': 1, 'Last': 3, 'time': 3, 'content': 3, 'was': 3, 'read.': 1, 'Modification': 1, '(mtime):': 1, 'modified.': 1, 'Change': 1, '(ctime):': 1, '(e.g.,': 1, 'permissions,': 1, 'owner)': 1, 'changed.': 1, 'Link': 3, 'Count:': 1, 'hard': 3, 'links': 1, 'pointing': 1, 'inode.': 3, 'Pointers': 1, 'Data': 1, 'Blocks:': 1, 'most': 2, 'critical': 1, 'part—these': 1, 'are': 1, 'disk': 1, 'addresses': 1, 'point': 1, 'blocks': 1, 'storage': 1, 'stored.': 1, 'Demonstration': 1, 'Examples': 1, "Let's": 1, 'use': 1, 'terminal': 1, 'see': 1, 'inodes': 1, 'action.': 1, 'Viewing': 1, 'Numbers': 1, 'ls': 4, 'command': 1, '-i': 1, 'option': 1, 'shows': 1, 'files.': 1, 'bash': 2, '$': 5, '-li': 3, '/etc/hosts': 2, '787795': 2, '-rw-r--r--': 4, '1': 2, 'root': 2, '241': 1, 'Oct': 4, '19': 1, '11:23': 1, 'Explanation:': 1, 'at': 3, 'beginning': 1, '/etc/hosts.': 1, 'rest': 1, '(permissions,': 1, 'links,': 1, 'size,': 1, 'etc.)': 1, 'stored': 3, 'within': 1, 'Core': 1, 'Concept:': 1, 'vs.': 1, 'This': 1, 'important': 1, 'concept': 1, 'grasp.': 1, 'filename': 1, 'not': 1, 'inode;': 1, "it's": 1, 'directory.': 1, 'Example:': 1, 'Creating': 1, 'Hard': 1, 'link': 3, 'essentially': 1, 'creating': 1, 'another': 1, 'directory': 1, 'entry': 1, '(another': 1, 'filename)': 1, 'points': 1, 'exact': 1, 'same': 1, '#': 5, 'Create': 2, 'echo': 1, '"This': 1, 'original': 1, 'data"': 1, '>': 1, 'original.txt': 6, 'Look': 1, 'count': 2, '1051234': 4, 'user': 6, '23': 3, '26': 3, '10:00': 3, '1,': 1, 'ln': 1, 'hardlink.txt': 3, 'Now': 1, 'look': 1, 'both': 1, 'files': 1, '2': 2}
# Word/s with maximum instances: ['the'] with 36 occurrences
